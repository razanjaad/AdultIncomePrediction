# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# **Data Pre-processing**

# %%
data = pd.read_csv("adult.csv")

# %%
data = data.dropna()

# %%
ll = LabelEncoder()
data["workclass"] = ll.fit_transform(data["workclass"])
data["income"] = ll.fit_transform(data["income"])
data["native-country"] = ll.fit_transform(data["native-country"])
data["education"] = ll.fit_transform(data["education"])
data["marital-status"] = ll.fit_transform(data["marital-status"])
data["occupation"] = ll.fit_transform(data["occupation"])
data["relationship"] = ll.fit_transform(data["relationship"])
data["race"] = ll.fit_transform(data["race"])
data["gender"] = ll.fit_transform(data["gender"])

# %% [markdown]
# **Data Visualition**

# %%
plt.matshow(data.corr())
plt.show()

# %% [markdown]
# **Correlation between attributes**

# %%
target = data["income"]
data = data.drop("income",axis=1)
x_train,x_test,y_train,y_test = train_test_split(data,target,test_size=0.2,random_state=42)
model = LogisticRegression()
model.fit(x_train,y_train)
scores = cross_val_score(model,x_train,y_train,cv=10)
print("The Validation accuracy is:",scores.mean())
pred = model.predict(x_test)
print("First 10 Actual class:",y_test[:10])

print("First 10 Predicted class:",pred[:10])

print("The testing accuracy is:",accuracy_score(y_test,pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
plt.scatter(data["fnlwgt"],data["hours-per-week"])
plt.title("hours-per-week with fnlwgt relationship")
plt.xlabel("fnlwgt")
plt.ylabel("hours-per-week")
plt.show()

# %%
plt.scatter(data["workclass"],target)
plt.title("target income with workclass relationship")
plt.xlabel("workclass")
plt.ylabel("income")
plt.show()

# %%
plt.scatter(data["native-country"],target)
plt.title("target income with native-country relationship")
plt.xlabel("native-country")
plt.ylabel("income")
plt.show()

# %%
plt.scatter(data["education"],target)
plt.title("target income with education relationship")
plt.xlabel("education")
plt.ylabel("income")
plt.show()

# %%
plt.scatter(data["occupation"],target)
plt.title("target income with occupation relationship")
plt.xlabel("occupation")
plt.ylabel("income")
plt.show()

# %%
plt.scatter(data["age"],data["fnlwgt"])
plt.title("fnlwgt with age relationship")
plt.xlabel("age")
plt.ylabel("fnlwgt")
plt.show()

# %%
plt.scatter(data["education"],data["native-country"])
plt.title("native-country with education relationship")
plt.xlabel("education")
plt.ylabel("native-country")
plt.show()
